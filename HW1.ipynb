# %% [markdown]
# <a href="https://colab.research.google.com/github/fernx-ks/PyThonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > กนกวรรณ แสนประดิษฐ์

# %%
print ("663020567-8")
# Out:
# 663020567-8
